# %% [markdown]
# # Projet Quotaclimat
#
# Les données des articles de presse ont été **scrapées depuis décembre 2022**. Les **titres** des articles de presse ainsi que des **méta-données** ont été récupérées. Les **données** sont présentes dans le fichier CSV nommé "quotaclimat_fulldataset.csv".

# %%
import pandas as pd

# %%
df_1 = pd.read_csv("quotaclimat_fulldataset_1.csv", index_col=0)
df_2 = pd.read_csv("quotaclimat_fulldataset_2.csv", index_col=0)
df = pd.concat([df_1, df_2])
df
# Out:
# C:\Users\PLB\AppData\Local\Temp\ipykernel_10008\2850025231.py:1: DtypeWarning: Columns (2,3,8,9,13,14,19,20,21,22,23) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_1 = pd.read_csv("quotaclimat_fulldataset_1.csv", index_col=0)
# C:\Users\PLB\AppData\Local\Temp\ipykernel_10008\2850025231.py:2: DtypeWarning: Columns (11,13,19,20,22,23) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_2 = pd.read_csv("quotaclimat_fulldataset_2.csv", index_col=0)
#                                                      url        news  \
# 0      https://www.bfmtv.com/paris/replay-emissions/b...         NaN
# 1      https://www.bfmtv.com/bfm-dici/replay-emission...         NaN
# 2      https://www.bfmtv.com/bfm-dici/une-grosse-cole...         NaN
# 3      https://www.bfmtv.com/meteo/la-meteo-pour-ce-d...         NaN
# 4      https://www.bfmtv.com/societe/france-danemark-...         NaN
# ...
